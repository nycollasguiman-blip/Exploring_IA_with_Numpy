# %% [markdown]
# # 0 - Importando bibliotecas
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definindo seed para resultados replicáveis
rng = np.random.default_rng(42)

# %% [markdown]
# # 1 - Regressão linear univariada
# ---
# ### 1.1 - Introdução
# A ideia é a partir de uma série de pontos $(x_1, y_1), (x_2, y_2), ..., (x_n, y_n)$ calcular uma reta que melhor se encaixa a esses pontos.
#
# <br>
#
# Equação geral da reta:
#
# $$
# \boxed{
# y = b + w*x \tag{1}
# }
# $$
#
# Nessa equação há duas váriaveis a dependente, $y$, e uma independente, $x$. De acordo com a equação 1, e com o que foi proposto, o problema se resume a encontrar $b$ e $w$ tal que:
#
# $$
# \begin{bmatrix}
# y_1\\
# y_2\\
# \vdots\\
# y_n
# \end{bmatrix} =
# \begin{bmatrix}
# 1 & x_1\\
# 1 & x_2\\
# \vdots & \vdots\\
# 1 & x_n
# \end{bmatrix}
# \begin{bmatrix}
# b\\
# w
# \end{bmatrix}
# $$
#
# Porém a igualdade só irá ser verdade se a reta passar exatamente sobre tais pontos, em um problema real isso é muito improvável. Portanto adicionando um termo de erro $[e_1, e_2, ..., e_n]^T$:
#
# $$
# \begin{bmatrix}
# y_1\\
# y_2\\
# \vdots\\
# y_n
# \end{bmatrix} =
# \begin{bmatrix}
# 1 & x_1\\
# 1 & x_2\\
# \vdots & \vdots\\
# 1 & x_n
# \end{bmatrix}
# \begin{bmatrix}
# b\\
# w
# \end{bmatrix} +
# \begin{bmatrix}
# e_1\\
# e_2\\
# \vdots \\
# e_n
# \end{bmatrix}
# $$
#
# e assim:
#
# $$
# \boxed{
# \begin{bmatrix}
# e_1\\
# e_2\\
# \vdots \\
# e_n
# \end{bmatrix} =
# \begin{bmatrix}
# y_1\\
# y_2\\
# \vdots\\
# y_n
# \end{bmatrix} -
# \begin{bmatrix}
# 1 & x_1\\
# 1 & x_2\\
# \vdots & \vdots\\
# 1 & x_n
# \end{bmatrix}
# \begin{bmatrix}
# b\\
# w
# \end{bmatrix} \tag{2}
# }
# $$
#
# Então a ideia por trás da regressão linear, replicavél para mais de uma váriavel independente, é reduzir ao máximo o vetor de erros.
#
# Para melhor vizualizar as contas:
#
# $$
# e =
# \begin{bmatrix}
# e_1\\
# e_2\\
# \vdots \\
# e_n
# \end{bmatrix} \qquad
# d =
# \begin{bmatrix}
# y_1\\
# y_2\\
# \vdots\\
# y_n
# \end{bmatrix} \qquad
# X =
# \begin{bmatrix}
# 1 & x_1\\
# 1 & x_2\\
# \vdots & \vdots\\
# 1 & x_n;
# \end{bmatrix} \qquad
# W =
# \begin{bmatrix}
# b\\
# w
# \end{bmatrix}
# $$

# %% [markdown]
# ### 1.2 - Criando testes
# Nessa seção é definido todos os dados para fazer os testes nas seções posteriores, considerando que os valores de $d$ são os da função original acrescentado de um ruído para cada coordenada $x$, assim o objetivo é a partir dos pontos construir uma reta e comparar com a original. Na prática não se tem a original, ela é utilizada nesse notebook para estudar os resultados da aplicação dos métodos matemáticos sobre os pontos com ruido e por fim comparar a reta construída pelos pontos com a reta original.

# %%
# Definindo reta original
W = np.random.uniform(-10, 10, (2, 1))
print(f"Valores escolhidos b = {W[0, 0]} e w = {W[1, 0]}")

# Definindo amostragem com ruído
n_amostras = 30
rng = np.random.default_rng()
ruido = rng.normal(0, 5, (n_amostras, 1)) #N(0,1)

# Montando data sets
x =  np.random.uniform(-10, 10, (n_amostras, 1))
X =  np.hstack((np.ones((n_amostras, 1)), x))
y =  X@W # Na prática não se sabe, nem o formato
d =  X@W + ruido # Na prática é o que se sabe

# Montando gráfico
plt.plot(x, y, label = "Reta original", color = "red")
plt.scatter(x, d, label = "Dados simulados")

plt.xlabel("Váriavel independente")
plt.ylabel("Váriavel dependente")
plt.legend()
plt.title("Dados originais e dados simulados")
plt.grid(True)
plt.show()
# Out:
# Valores escolhidos b = -4.014668652585158 e w = 8.646332808060787

# %% [markdown]
# ### 1.3 - Minimizando erro
# A ideia é utilizar a bordagem dos mínimos quadrados para calcular o erro e, para o problema em questão, utilizar cálculo derivar a expressão do erro e igualar chegando em um sistema te equações cuja solução é um $W$ que minimiza o erro.
#
# Método dos mínimos quadrados:
# $$
# \sum_{i = 1}^{n} e_i^2 = \sum_{i = 1}^{n} (d_i - b - wx_i)^2
# $$
#
# $$
# \frac{\partial}{\partial b}
# \left(
# \sum_{i=1}^{n}(d_i-b-wx_i)^2
# \right)
# =
# -2\sum_{i=1}^{n}(d_i-b-wx_i)
# =
# -2\sum_{i=1}^{n}e_i
# $$
#
# $$
# \frac{\partial}{\partial w}
# \left(
# \sum_{i=1}^{n}(d_i-b-wx_i)^2
# \right)
# =
# -2\sum_{i=1}^{n}x_i(d_i-b-wx_i)
# =
# -2\sum_{i=1}^{n}x_ie_i
# $$
#
# Juntando as duas expressões em uma por meio de matrizes:
#
# $$
# \frac{\partial}{\partial W}
# \left(
# \sum_{i=1}^{n}(e_i)^2
# \right)
# =
# -2X^Te
# =
# -2X^T(d - XW)
# $$
#
# Igualando esse resultado a zero o $W$ correspondente pode ser calculado e os valores de b e w serão tais que esse ponto é necessariamente um mínimo, pois a função custo é a soma de termos quadráticos, que é sempre não negativa e convexa, nomeando a solução do sistema de equação como $W_0$, $b_0$ e $w_0$:
#
# $$
# -2X^T(d - XW_0) = 0
# $$
#
# $$
# X^Td - X^TXW_0 = 0
# $$
#
# $$
# \boxed{
# X^TXW_0 = X^Td \tag{3}
# }
# $$
#
# Assim, com $W_0 = \begin{bmatrix} b_0 \\ w_0 \end{bmatrix}$,  $b_0$ e $w_0$ aplicados na equação 1 geram a reta que melhor se ajusta aos pontos segundo os critério dos mínimos quadrados.

# %% [markdown]
# ### 1.4 - Gerando resultados
# Simplesmente resolvendo os sistema pelo numpy

# %%
W0 = np.linalg.solve(X.T@X, X.T@d)

# %%
print(
    f"Da reta original:\nb = {W[0,0]}\nw = {W[1,0]}\n"
    f"\nDos mínimos quadrados:\nb0 = {W0[0,0]}\nw0 = {W0[1,0]}"
)
# Out:
# Da reta original:
# b = -4.014668652585158
# w = 8.646332808060787
#
# Dos mínimos quadrados:
# b0 = -6.455537864226306
# w0 = 8.762073133484249

# %%
# Plotando resultado
y_0 = X@W0
plt.plot(x, y, color = "red") # Reta original
plt.plot(x, y_0, color = "green") # Reta calculada
plt.scatter(x, d, color = "blue") # Pontos do data set
plt.show()

erro_final = np.sum((y - y_0)**2)
print(f"Erro final = {erro_final}")
# Out:
# Erro final = 197.42178925819601

# %% [markdown]
# A maioria dos conceitos apresentados aqui também é utilizada no estudo e na aplicação de redes neurais. Foi proposital o uso de (b) e (w) na Equação (1), pois esses parâmetros correspondem ao viés (bias) e ao peso (weight), respectivamente, nomenclatura amplamente utilizada em aprendizado de máquina.
#
# Além disso, o conjunto de dados utilizado para calcular a reta foi tratado como um único conjunto de pontos. Em uma aplicação prática, esse conjunto normalmente é dividido em duas partes: conjunto de treino, utilizado para ajustar os parâmetros do modelo (encontrar a reta), e conjunto de testes, utilizado apenas para avaliar o desempenho do modelo em dados que não foram usados durante o treinamento.
#
# Por fim, este exemplo apresenta apenas o caso mais simples de regressão linear. Apesar disso, os conceitos de função custo, minimização do erro, ajuste de parâmetros e representação matricial servem como base para algoritmos mais avançados, incluindo regressão múltipla, regressão logística e redes neurais artificiais.

# %% [markdown]
# # 2 - Regressão linear multivariada
# ---
# ### 2.1 - Introdução
# Por uma simetria do problema todo o resultado obtido pela seção 1 pode ser aplicado para o caso em que multiplas variáveis estão envolvidas seguindo as seguinte ampliações:
#
# Os pontos são multidimencionais, $n$ pontos com $m$ características:
#
# $$
# (x_{11}, x_{12}, \ldots, x_{1m}, y_1),\;
# (x_{21}, x_{22}, \ldots, x_{2m}, y_2),\;
# \ldots,\;
# (x_{N1}, x_{N2}, \ldots, x_{Nm}, y_N)
# $$
#
# A equação 1 não se torna:
#
# $$
# \boxed{
# y = b + w_1x_1 + w_2x_2 + \cdots + w_mx_m \tag{4}
# }
# $$
#
# A equação 2 se torna:
#
# $$
# \boxed{
# \begin{bmatrix}
# e_1\\
# e_2\\
# \vdots\\
# e_n
# \end{bmatrix}
# =
# \begin{bmatrix}
# y_1\\
# y_2\\
# \vdots\\
# y_n
# \end{bmatrix}
# -
# \begin{bmatrix}
# 1 & x_{11} & x_{12} & \cdots & x_{1m}\\
# 1 & x_{21} & x_{22} & \cdots & x_{2m}\\
# \vdots & \vdots & \vdots & \ddots & \vdots\\
# 1 & x_{n1} & x_{n2} & \cdots & x_{nm}
# \end{bmatrix}
# \begin{bmatrix}
# b\\
# w_1\\
# w_2\\
# \vdots\\
# w_m
# \end{bmatrix}
# \tag{5}
# }
# $$
#
# Com:
#
# $$
# e =
# \begin{bmatrix}
# e_1\\
# e_2\\
# \vdots\\
# e_n
# \end{bmatrix}
# \qquad
# d =
# \begin{bmatrix}
# y_1\\
# y_2\\
# \vdots\\
# y_n
# \end{bmatrix}
# \qquad
# X =
# \begin{bmatrix}
# 1 & x_{11} & x_{12} & \cdots & x_{1m}\\
# 1 & x_{21} & x_{22} & \cdots & x_{2m}\\
# \vdots & \vdots & \vdots & \ddots & \vdots\\
# 1 & x_{n1} & x_{n2} & \cdots & x_{nm}
# \end{bmatrix}
# \qquad
# W =
# \begin{bmatrix}
# b\\
# w_1\\
# w_2\\
# \vdots\\
# w_m
# \end{bmatrix}
# $$
#
# E seguindo os mesmos passos das contas apresentadas na seção 1 a equação 3 não muda!
# $$
# X^TXW_0 = X^Td
# $$
#
# Portando basta penas resolver o sistema de equações para encontrar o $W_0$ que contém o viés $b_0$ e cada peso $w_{10}$, $w_{20}$, ..., $w_{m0}$ que melhor ajusta um superplano ("reta" de várias dimensões) segundo o critério dos mínimos quadrados.

# %% [markdown]
# ### 2.2 - Criando testes
# Infelizmente não é possível gerar o gráfico para vizualização do superplano, mas a ideia é a mesma que o que foi feito na seção 1.

# %%
n = 10000 # 10000 pontos, ou amostras
m = 100 # 100 características

W =  np.random.uniform(-100, 100, (m + 1, 1))
x = np.random.uniform(-10, 10, (n, m))
X = np.hstack((np.ones((n, 1)), x))
y = X@W

ruido = rng.normal(0, 5, (n, 1))
d = y + ruido

# %% [markdown]
# ### 2.3 - Gerando resultados

# %%
W0 = np.linalg.solve(X.T@X, X.T@d)

# %%
np.sum((W - W0)**2)
# Out:
# np.float64(0.007755443044623968)

# %% [markdown]
# Como o cálculo do erro não é muito esclarecedor para avaliar resultados (por enquanto) e como a expressão original é definida na seção anterior, na prática não se tem mas esse notebook é um estudo, o quão bom o resultado da abordagem dos mínimos quadrados é pode ser avaliado com o quanto $W_0$ está próximo de $W$, de fato são muito próximos, evidênciando o funcionamento do método.

# %%
# Exibindo a diferença W-W0 com os indices
plt.plot(np.arange(0, m+1).reshape(-1,1), W-W0)
plt.title("indice x W-W0 ")
plt.xlabel("indice")
plt.ylabel("Wi-W0i")
plt.show()

# %% [markdown]
# A partir do gráfico fica ainda mais explicito a aproximação de W0 com W.

# %%
erro_final = np.sum((y - X@W0)**2)
print(f"Erro final = {erro_final}") # É o menor segundo o método dos mínimos quadrados
# Out:
# Erro final = 2532.5021170327163

# %%
# Mostrando que apenas chutando W0 não é possível adquirir bons resultados
numero_testes = 10
for i in range(1, numero_testes+1):
    W_teste = np.random.uniform(-100,100, (m+1, 1))
    Erro_alternativo = np.sum((y - X@W_teste)**2)
    print(f"{i}° erro = {Erro_alternativo}")
# Serve também para ter uma referência do quando o erro final é pequeno
# Out:
# 1° erro = 238486802060.5525
# 2° erro = 217455717651.84546
# 3° erro = 224172539238.82812
# 4° erro = 214710698701.86502
# 5° erro = 190999238608.3833
# 6° erro = 190172015724.43555
# 7° erro = 156239720160.65637
# 8° erro = 207310888370.34988
# 9° erro = 204739058228.2549
# 10° erro = 205760569727.7414

# %% [markdown]
# # 3 - Regressão polinomial
# ---
# ### 3.1 - Introdução
# Utilizando os pontos da seção 1: ${(x_1, y_1), (x_2, y_2), ..., (x_n, y_n)}$ dessa vez o objetivo é ajustar um polinômio aos pontos utilizando uma ampliação parecida com o que foi feito na seção 2, a equação 4 do modelo se torna:
#
# $$
# \boxed{
# y = b + w_1x + w_2x^2 + ... + w_mx^m \tag{6}
# }
# $$
#
# E portanto a equação 5 se torna:
#
# $$
# \boxed{
# \begin{bmatrix}
# e_1\\
# e_2\\
# \vdots\\
# e_n
# \end{bmatrix}
# =
# \begin{bmatrix}
# y_1\\
# y_2\\
# \vdots\\
# y_n
# \end{bmatrix}
# -
# \begin{bmatrix}
# 1 & x_1 & x_1^2 & \cdots & x_1^m\\
# 1 & x_2 & x_2^2 & \cdots & x_2^m\\
# \vdots & \vdots & \vdots & \ddots & \vdots\\
# 1 & x_n & x_n^2 & \cdots & x_n^m
# \end{bmatrix}
# \begin{bmatrix}
# b\\
# w_1\\
# w_2\\
# \vdots\\
# w_m
# \end{bmatrix}
# \tag{7}
# }
# $$
#
# Com:
# $$
# e =
# \begin{bmatrix}
# e_1\\
# e_2\\
# \vdots\\
# e_n
# \end{bmatrix}
# \qquad
# d =
# \begin{bmatrix}
# y_1\\
# y_2\\
# \vdots\\
# y_n
# \end{bmatrix}
# \qquad
# X =
# \begin{bmatrix}
# 1 & x_1 & x_1^2 & \cdots & x_1^m\\
# 1 & x_2 & x_2^2 & \cdots & x_2^m\\
# \vdots & \vdots & \vdots & \ddots & \vdots\\
# 1 & x_n & x_n^2 & \cdots & x_n^m
# \end{bmatrix}
# \qquad
# W =
# \begin{bmatrix}
# b\\
# w_1\\
# w_2\\
# \vdots\\
# w_m
# \end{bmatrix}
# $$
#
# E da mesma maneira os coeficientes podem ser encontrados por:
# $$
# X^TXW_0 = X^Td
# $$
#
# Tal que $W_0$ contém os coeficientes do polinômio da equação 6 que minimiza o erro do ajuste aos pontos segundo o critério dos mínimos quadrados.

# %% [markdown]
# ### 3.2 - Criando testes
# Dessa vez o teste será criado não com base em uma reta mas com base em  três funções distintas: $sen(x)$, $x^2$ e $e^x$, ($e$ é o número de euler), como nas últimas vezes a ideia é partir da função original, na prática não a temos mas esse notebook é de estudos, e escolher pontos dessa fução como amostra e por fim acrescentar ruido, assim esses pontos serão usados para construir a função (treinamento) que melhor se ajusta a tais pontos.

# %%
# Número de pontos
n = 50

# Para plotar funções originais
x_plot = np.arange(-5, 5, 0.25)
plot_sen = np.sin(x_plot)
plot_x_2 = x_plot**2
plot_e_x = np.exp(x_plot)

# Para plotar as n amostras
x = np.random.uniform(-5, 5, (n, 1))
idx = np.argsort(x[:, 0]) # Organiza x em ordem crescente
x = x[idx]
ruido = rng.normal(0, 1, (n, 1))
d_sen = np.sin(x) + ruido
d_x_2 = x**2 + ruido
d_e_x = np.exp(x) + ruido

# Organizando 3 gráficos
fig, axs = plt.subplots(3, 1, figsize = (15, 15))
graficos = [plot_sen, plot_x_2, plot_e_x]
amostras = [d_sen, d_x_2, d_e_x]
titulos = ["Gráfico do sen(x)", "Gráfico do x^2", "Gráfico do e^x"]
ylabels = ["sen(x)", "x^2", "e^x"]

# Exibindo os 3 gráficos
for ax, y, titulo, ylabel, amostra in zip(axs, graficos, titulos, ylabels, amostras):
    ax.plot(x_plot, y, color="red", label = "Função original")
    ax.scatter(x, amostra, color = "blue", label = "amostras")
    ax.set_title(titulo)
    ax.set_xlabel("x")
    ax.set_ylabel(ylabel)
    ax.grid(True)
    ax.legend()
    ax.set_xlim(-5, 5)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.3 - Gerando resultados

# %%
# Grau do polinômio
m = 5 # Altere o grau aqui

# Montando X
X = np.ones((n, 1))
for i in range(1, m+1):
    X = np.hstack((X, x**i))

# Cálculo dos coeficientes
W0_sen = np.linalg.solve(X.T@X, X.T@d_sen)
W0_x_2 = np.linalg.solve(X.T@X, X.T@d_x_2)
W0_e_x = np.linalg.solve(X.T@X, X.T@d_e_x)

coeficientes = [W0_sen, W0_x_2, W0_e_x]

# Organizando 3 gráficos
fig, axs = plt.subplots(3, 1, figsize = (15, 15))
graficos = [plot_sen, plot_x_2, plot_e_x]
amostras = [d_sen, d_x_2, d_e_x]
titulos = ["Gráfico do sen(x)", "Gráfico do x^2", "Gráfico do e^x"]
ylabels = ["sen(x)", "x^2", "e^x"]

# Plotando os 3 gráficos
for ax, y, titulo, ylabel, amostra, coef in zip(axs, graficos, titulos, ylabels, amostras, coeficientes):
    ax.plot(x_plot, y, color="red", label = "Função original")
    ax.scatter(x, amostra, color = "blue", label = "amostras")
    ax.plot(x, X@coef, color = "green", label = "Função prevista")
    ax.set_title(titulo)
    ax.set_xlabel("x")
    ax.set_ylabel(ylabel)
    ax.grid(True)
    ax.legend()
    ax.set_xlim(-5, 5)

# %% [markdown]
# A partir do código acima é possível visualizar o resultado da regressão polinômial escolhendo o grau do polinômio que se deseja utilizar para se ajustar aos dados. Os dados são as amostras (pontos azuis) retiradas das funções originais (linha vermelha) adicionadas de um ruído Gaussiano de variância 1 e média zero, a partir desses pontos é calculado os coeficientes do polinômio  que melhor se ajusta (linha verde) segundo o critério dos mínimos quadrados. A questão prícipal a se observar é que existe um grau ótimo que polinômio ter para se bem se ajustar a cada tipo de função original. Se o grau for 1 o problema se reduz exatamente para o da seção 1 e o resultado não é bom para nenhum caso. Se o grau for 2, o polinômio consegue capturar perfeitamente a curvatura da função original $x^2$, mas o ajuste final não será idêntico a ela, mas de pequeno erro, porque o modelo também tenta absorver o ruído inserido nas amostras. Para as funções $\text{sen}(x)$ e $e^x$, o grau 2 ainda é insuficiente para acompanhar suas formas. No grau 4 o modelo polinômial começa a capturar efetivamente a curva de $e^x$. E, por fim, no grau 5 também é capturado a curva de $\text{sen}(x)$.
#
# É interessante reparar que se o grau for grande demais (100 por exemplo) começa a ocorrer o fenômeno chamado de overfiting, onde a curva do polinômio começa a se ajustar ao ruido Gaussiano acrescentado e, consequêntemente, também há perda de generalização, ou seja, a curva do polinômio se aproxima tanto dos pontos usados para construí-la que, se a curva prevista for testada em pontos que não foram usados no processo de construção, o erro será muito grande.
#
# Por fim, vale lembrar do paralelismo que há no que foi feito nesse notebook com o que é feito em redes neurais.
